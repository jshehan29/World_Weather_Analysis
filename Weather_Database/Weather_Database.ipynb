# %%
# Import dependencies
import pandas as pd
import numpy as np
import time
import requests

from citipy import citipy

from config_weather import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# ----------------------------------------

# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
print(f"I have {len(cities)} cities.")
# Out:
# I have 785 cities.

# %%
# Starting URL or Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of hte logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    time.sleep(1.1) # Added to comply with 60 requests per minute limit with free OWM API
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1 #Should this be incrementing??
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to record count
    record_count += 1
    
    # ------------------------------------
    # Run an API request for each of teh cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list
        city_data.append({"City":city.title(),
                         "Country":city_country,
                         "Lat":city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed":city_wind,
                         "Current Description":city_desc})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that data loading is complete
print("---------------------------")
print("Data Retrieval Complete    ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | roma
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | qesarya
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | winchester
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | kaitangata
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | pingliang
# Processing Record 16 of Set 1 | encheng
# Processing Record 17 of Set 1 | katangli
# Processing Record 18 of Set 1 | pokosnoye
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | vao
# Processing Record 22 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | havoysund
# Processing Record 27 of Set 1 | buala
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | ugoofaaru
# Processing Record 30 of Set 1 | iwaki
# Processing Record 31 of Set 1 | poum
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | gushikawa
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | palauig
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | severodvinsk
# Processing Record 41 of Set 1 | sao gabriel da cachoeira
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | pocone
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | shingu
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | esmeralda
# Processing Record 48 of Set 1 | seoul
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | tuatapere
# Processing Record 4 of Set 2 | kloulklubed
# Processing Record 5 of Set 2 | pantai remis
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | gijon
# Processing Record 8 of Set 2 | sebinkarahisar
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | caravelas
# Processing Record 12 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | traiguen
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | dongsheng
# Processing Record 18 of Set 2 | stranraer
# Processing Record 19 of Set 2 | san miguel ixtahuacan
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | mayo
# Processing Record 22 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | bangassou
# Processing Record 25 of Set 2 | hamilton
# Processing Record 26 of Set 2 | springbok
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | katy
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | padang
# Processing Record 31 of Set 2 | raudeberg
# Processing Record 32 of Set 2 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 33 of Set 2 | waitati
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | bengkulu
# Processing Record 36 of Set 2 | beringovskiy
# Processing Record 37 of Set 2 | ballina
# Processing Record 38 of Set 2 | erdenet
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | bati
# Processing Record 41 of Set 2 | palana
# Processing Record 42 of Set 2 | sabya
# Processing Record 43 of Set 2 | vung tau
# Processing Record 44 of Set 2 | leningradskiy
# Processing Record 45 of Set 2 | tigil
# Processing Record 46 of Set 2 | rafai
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | zlotow
# Processing Record 49 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 50 of Set 2 | cam ranh
# Processing Record 1 of Set 3 | besancon
# Processing Record 2 of Set 3 | boa vista
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | nhulunbuy
# Processing Record 5 of Set 3 | turbat
# Processing Record 6 of Set 3 | pervomayskoye
# Processing Record 7 of Set 3 | ahuimanu
# Processing Record 8 of Set 3 | camacari
# Processing Record 9 of Set 3 | general roca
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | oussouye
# Processing Record 12 of Set 3 | kamenka
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | santa cruz
# Processing Record 15 of Set 3 | bathsheba
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | burns lake
# Processing Record 19 of Set 3 | stony plain
# Processing Record 20 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 3 | araouane
# Processing Record 22 of Set 3 | waingapu
# Processing Record 23 of Set 3 | tulum
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | ukiah
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | saint-pierre
# Processing Record 30 of Set 3 | jaisalmer
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | ziway
# Processing Record 34 of Set 3 | aswan
# Processing Record 35 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | sao filipe
# Processing Record 38 of Set 3 | ginda
# Processing Record 39 of Set 3 | campos novos
# Processing Record 40 of Set 3 | landerneau
# Processing Record 41 of Set 3 | tyulyachi
# Processing Record 42 of Set 3 | ornskoldsvik
# Processing Record 43 of Set 3 | ribeira grande
# Processing Record 44 of Set 3 | itoman
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | kyren
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | fuerte olimpo
# Processing Record 49 of Set 3 | methoni
# Processing Record 50 of Set 3 | vaini
# Processing Record 1 of Set 4 | maarianhamina
# Processing Record 2 of Set 4 | sangar
# Processing Record 3 of Set 4 | broken hill
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | lake city
# Processing Record 6 of Set 4 | tazovskiy
# Processing Record 7 of Set 4 | new albany
# Processing Record 8 of Set 4 | xichang
# Processing Record 9 of Set 4 | talara
# Processing Record 10 of Set 4 | nizwa
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | babushkin
# Processing Record 13 of Set 4 | fort nelson
# Processing Record 14 of Set 4 | benalla
# Processing Record 15 of Set 4 | astoria
# Processing Record 16 of Set 4 | kashi
# Processing Record 17 of Set 4 | grand gaube
# Processing Record 18 of Set 4 | bredasdorp
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | santa maria
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | ola
# Processing Record 23 of Set 4 | college
# Processing Record 24 of Set 4 | husavik
# Processing Record 25 of Set 4 | dzilam gonzalez
# Processing Record 26 of Set 4 | ontario
# Processing Record 27 of Set 4 | severnoye
# Processing Record 28 of Set 4 | adre
# Processing Record 29 of Set 4 | tutoia
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | weihai
# Processing Record 32 of Set 4 | longyearbyen
# Processing Record 33 of Set 4 | wattegama
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | kalmunai
# Processing Record 36 of Set 4 | peruibe
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 4 | coihaique
# Processing Record 40 of Set 4 | coronado
# Processing Record 41 of Set 4 | roblin
# Processing Record 42 of Set 4 | burnie
# Processing Record 43 of Set 4 | assiniboia
# Processing Record 44 of Set 4 | ambon
# Processing Record 45 of Set 4 | brokopondo
# Processing Record 46 of Set 4 | rio grande
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | changji
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | isangel
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | sitio novo do tocantins
# Processing Record 3 of Set 5 | cabo san lucas
# Processing Record 4 of Set 5 | jinka
# Processing Record 5 of Set 5 | isiolo
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | khrebtovaya
# Processing Record 8 of Set 5 | kazachinskoye
# Processing Record 9 of Set 5 | port blair
# Processing Record 10 of Set 5 | baijiantan
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | jutai
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | umm lajj
# Processing Record 15 of Set 5 | tautira
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | inirida
# Processing Record 18 of Set 5 | fortuna
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | milkovo
# Processing Record 21 of Set 5 | tayoltita
# Processing Record 22 of Set 5 | prince george
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | eufaula
# Processing Record 25 of Set 5 | waipawa
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | bozoum
# Processing Record 29 of Set 5 | ellisras
# Processing Record 30 of Set 5 | oum hadjer
# Processing Record 31 of Set 5 | san quintin
# Processing Record 32 of Set 5 | along
# Processing Record 33 of Set 5 | antofagasta
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | hilo
# Processing Record 37 of Set 5 | aylesbury
# Processing Record 38 of Set 5 | skibbereen
# Processing Record 39 of Set 5 | amapa
# Processing Record 40 of Set 5 | ternate
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 5 | panama city
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | shwebo
# Processing Record 46 of Set 5 | mount isa
# Processing Record 47 of Set 5 | trenggalek
# Processing Record 48 of Set 5 | namibe
# Processing Record 49 of Set 5 | qui nhon
# Processing Record 50 of Set 5 | el tocuyo
# Processing Record 1 of Set 6 | itarema
# Processing Record 2 of Set 6 | dukat
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | manaure
# Processing Record 5 of Set 6 | khatanga
# Processing Record 6 of Set 6 | hambantota
# Processing Record 7 of Set 6 | kemijarvi
# Processing Record 8 of Set 6 | kampot
# Processing Record 9 of Set 6 | hailar
# Processing Record 10 of Set 6 | myitkyina
# Processing Record 11 of Set 6 | thinadhoo
# Processing Record 12 of Set 6 | shu
# Processing Record 13 of Set 6 | nang rong
# Processing Record 14 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 6 | rajula
# Processing Record 16 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 6 | outram
# Processing Record 18 of Set 6 | sabang
# Processing Record 19 of Set 6 | maralal
# Processing Record 20 of Set 6 | tual
# Processing Record 21 of Set 6 | avera
# Processing Record 22 of Set 6 | tiarei
# Processing Record 23 of Set 6 | svobodnyy
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | mezhdurechenskiy
# Processing Record 26 of Set 6 | mahibadhoo
# Processing Record 27 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 6 | amahai
# Processing Record 29 of Set 6 | kropotkin
# Processing Record 30 of Set 6 | oranjemund
# Processing Record 31 of Set 6 | nyagan
# Processing Record 32 of Set 6 | half moon bay
# Processing Record 33 of Set 6 | egvekinot
# Processing Record 34 of Set 6 | alice town
# Processing Record 35 of Set 6 | yerbogachen
# Processing Record 36 of Set 6 | nome
# Processing Record 37 of Set 6 | gornyy
# Processing Record 38 of Set 6 | bitlis
# Processing Record 39 of Set 6 | kosh-agach
# Processing Record 40 of Set 6 | north bend
# Processing Record 41 of Set 6 | alta floresta
# Processing Record 42 of Set 6 | ketchikan
# Processing Record 43 of Set 6 | victor harbor
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | helong
# Processing Record 46 of Set 6 | bagdarin
# Processing Record 47 of Set 6 | machinga
# Processing Record 48 of Set 6 | arlit
# Processing Record 49 of Set 6 | okakarara
# Processing Record 50 of Set 6 | anadyr
# Processing Record 1 of Set 7 | hanko
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | puerto carreno
# Processing Record 4 of Set 7 | mujiayingzi
# Processing Record 5 of Set 7 | provost
# Processing Record 6 of Set 7 | george
# Processing Record 7 of Set 7 | bintulu
# Processing Record 8 of Set 7 | ashta
# Processing Record 9 of Set 7 | provideniya
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 7 | dalvik
# Processing Record 13 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 7 | torbay
# Processing Record 15 of Set 7 | westport
# Processing Record 16 of Set 7 | kirkwall
# Processing Record 17 of Set 7 | constitucion
# Processing Record 18 of Set 7 | ust-omchug
# Processing Record 19 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 7 | bend
# Processing Record 21 of Set 7 | ikeda
# Processing Record 22 of Set 7 | terney
# Processing Record 23 of Set 7 | glomfjord
# Processing Record 24 of Set 7 | benguela
# Processing Record 25 of Set 7 | fare
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | saint-fabien
# City not found. Skipping...
# Processing Record 28 of Set 7 | bambous virieux
# Processing Record 29 of Set 7 | ribeira brava
# Processing Record 30 of Set 7 | novovasylivka
# Processing Record 31 of Set 7 | machaneng
# Processing Record 32 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 7 | hovd
# Processing Record 34 of Set 7 | quzhou
# Processing Record 35 of Set 7 | barisal
# Processing Record 36 of Set 7 | setermoen
# Processing Record 37 of Set 7 | ambulu
# Processing Record 38 of Set 7 | tasiilaq
# Processing Record 39 of Set 7 | wadi musa
# Processing Record 40 of Set 7 | zaysan
# Processing Record 41 of Set 7 | matadi
# Processing Record 42 of Set 7 | the valley
# Processing Record 43 of Set 7 | puerto penasco
# Processing Record 44 of Set 7 | jarjis
# City not found. Skipping...
# Processing Record 45 of Set 7 | saint george
# Processing Record 46 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 7 | abonnema
# Processing Record 48 of Set 7 | inhambane
# Processing Record 49 of Set 7 | the pas
# Processing Record 50 of Set 7 | saint-joseph
# Processing Record 1 of Set 8 | asyut
# Processing Record 2 of Set 8 | sosnovskoye
# Processing Record 3 of Set 8 | bartica
# Processing Record 4 of Set 8 | rocha
# Processing Record 5 of Set 8 | port-gentil
# Processing Record 6 of Set 8 | mamallapuram
# Processing Record 7 of Set 8 | san mauro torinese
# Processing Record 8 of Set 8 | hualmay
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | batagay
# Processing Record 11 of Set 8 | tuy hoa
# Processing Record 12 of Set 8 | santa clara
# Processing Record 13 of Set 8 | playia
# City not found. Skipping...
# Processing Record 14 of Set 8 | truro
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 8 | nouadhibou
# Processing Record 17 of Set 8 | lata
# Processing Record 18 of Set 8 | kokopo
# Processing Record 19 of Set 8 | mokhsogollokh
# Processing Record 20 of Set 8 | griffith
# Processing Record 21 of Set 8 | nacogdoches
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | tomari
# Processing Record 24 of Set 8 | basco
# Processing Record 25 of Set 8 | adiake
# Processing Record 26 of Set 8 | shache
# Processing Record 27 of Set 8 | pangody
# Processing Record 28 of Set 8 | khirkiya
# Processing Record 29 of Set 8 | irara
# Processing Record 30 of Set 8 | menongue
# Processing Record 31 of Set 8 | souillac
# Processing Record 32 of Set 8 | chumikan
# Processing Record 33 of Set 8 | nampula
# Processing Record 34 of Set 8 | tiksi
# Processing Record 35 of Set 8 | muravlenko
# Processing Record 36 of Set 8 | nemuro
# Processing Record 37 of Set 8 | mehamn
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | sola
# Processing Record 40 of Set 8 | khvorostyanka
# Processing Record 41 of Set 8 | ullapool
# Processing Record 42 of Set 8 | luderitz
# Processing Record 43 of Set 8 | morondava
# Processing Record 44 of Set 8 | adrar
# Processing Record 45 of Set 8 | nawa
# Processing Record 46 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 8 | villa maria
# Processing Record 48 of Set 8 | mananjary
# Processing Record 49 of Set 8 | vostok
# Processing Record 50 of Set 8 | guider
# Processing Record 1 of Set 9 | nanortalik
# Processing Record 2 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 9 | saldanha
# Processing Record 4 of Set 9 | sokoni
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | kuching
# Processing Record 7 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 9 | ibra
# Processing Record 10 of Set 9 | chicama
# Processing Record 11 of Set 9 | camacha
# Processing Record 12 of Set 9 | ahipara
# Processing Record 13 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 9 | grindavik
# Processing Record 15 of Set 9 | stubbekobing
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | rostaq
# City not found. Skipping...
# Processing Record 18 of Set 9 | anori
# Processing Record 19 of Set 9 | irbit
# Processing Record 20 of Set 9 | caxito
# Processing Record 21 of Set 9 | rio gallegos
# Processing Record 22 of Set 9 | sassandra
# Processing Record 23 of Set 9 | maloyaz
# City not found. Skipping...
# Processing Record 24 of Set 9 | wanning
# Processing Record 25 of Set 9 | costa rica
# Processing Record 26 of Set 9 | kulhudhuffushi
# Processing Record 27 of Set 9 | dicabisagan
# Processing Record 28 of Set 9 | yagodnoye
# Processing Record 29 of Set 9 | los llanos de aridane
# Processing Record 30 of Set 9 | japura
# Processing Record 31 of Set 9 | sioux lookout
# Processing Record 32 of Set 9 | goderich
# Processing Record 33 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 9 | guerrero negro
# Processing Record 35 of Set 9 | huaihua
# Processing Record 36 of Set 9 | ipixuna
# Processing Record 37 of Set 9 | saint-francois
# Processing Record 38 of Set 9 | jacarezinho
# Processing Record 39 of Set 9 | maragogi
# Processing Record 40 of Set 9 | nanning
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | phonhong
# Processing Record 43 of Set 9 | acajutla
# Processing Record 44 of Set 9 | hofn
# Processing Record 45 of Set 9 | abbeville
# Processing Record 46 of Set 9 | kichera
# Processing Record 47 of Set 9 | neufchateau
# Processing Record 48 of Set 9 | soderhamn
# Processing Record 49 of Set 9 | ngunguru
# Processing Record 50 of Set 9 | kutum
# Processing Record 1 of Set 10 | thompson
# Processing Record 2 of Set 10 | kommunisticheskiy
# Processing Record 3 of Set 10 | kholodnyy
# Processing Record 4 of Set 10 | fortuna foothills
# Processing Record 5 of Set 10 | valparaiso
# Processing Record 6 of Set 10 | nishihara
# Processing Record 7 of Set 10 | requena
# Processing Record 8 of Set 10 | honiara
# Processing Record 9 of Set 10 | wad madani
# Processing Record 10 of Set 10 | krasnyy chikoy
# Processing Record 11 of Set 10 | labrea
# Processing Record 12 of Set 10 | yangambi
# Processing Record 13 of Set 10 | pietersburg
# Processing Record 14 of Set 10 | igrim
# Processing Record 15 of Set 10 | nuuk
# Processing Record 16 of Set 10 | chumphon
# Processing Record 17 of Set 10 | olafsvik
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | lakes entrance
# Processing Record 20 of Set 10 | berlevag
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | laguna
# Processing Record 23 of Set 10 | batticaloa
# Processing Record 24 of Set 10 | cabedelo
# Processing Record 25 of Set 10 | kimbe
# Processing Record 26 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 27 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 10 | maine-soroa
# Processing Record 29 of Set 10 | stromness
# Processing Record 30 of Set 10 | zemio
# Processing Record 31 of Set 10 | zonguldak
# Processing Record 32 of Set 10 | anloga
# Processing Record 33 of Set 10 | chuzhou
# Processing Record 34 of Set 10 | uaua
# Processing Record 35 of Set 10 | port keats
# Processing Record 36 of Set 10 | port hedland
# Processing Record 37 of Set 10 | narsaq
# Processing Record 38 of Set 10 | churapcha
# Processing Record 39 of Set 10 | buin
# Processing Record 40 of Set 10 | ambunti
# Processing Record 41 of Set 10 | plettenberg bay
# Processing Record 42 of Set 10 | mantua
# Processing Record 43 of Set 10 | raton
# Processing Record 44 of Set 10 | khor
# Processing Record 45 of Set 10 | namatanai
# Processing Record 46 of Set 10 | sydney
# Processing Record 47 of Set 10 | puerto colombia
# Processing Record 48 of Set 10 | hadejia
# Processing Record 49 of Set 10 | stornoway
# Processing Record 50 of Set 10 | lithgow
# Processing Record 1 of Set 11 | grojec
# Processing Record 2 of Set 11 | paita
# Processing Record 3 of Set 11 | progreso
# Processing Record 4 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 11 | moose factory
# Processing Record 6 of Set 11 | safranbolu
# Processing Record 7 of Set 11 | seminole
# Processing Record 8 of Set 11 | abrau-dyurso
# Processing Record 9 of Set 11 | baiyin
# Processing Record 10 of Set 11 | monrovia
# Processing Record 11 of Set 11 | saint-dizier
# Processing Record 12 of Set 11 | karasuk
# Processing Record 13 of Set 11 | ojinaga
# Processing Record 14 of Set 11 | hervey bay
# Processing Record 15 of Set 11 | brownfield
# Processing Record 16 of Set 11 | envira
# Processing Record 17 of Set 11 | hoa binh
# Processing Record 18 of Set 11 | reconquista
# Processing Record 19 of Set 11 | bambanglipuro
# Processing Record 20 of Set 11 | yulara
# Processing Record 21 of Set 11 | vuktyl
# Processing Record 22 of Set 11 | zhangjiakou
# Processing Record 23 of Set 11 | smithers
# Processing Record 24 of Set 11 | vila franca do campo
# Processing Record 25 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 26 of Set 11 | nevelsk
# Processing Record 27 of Set 11 | hebertville
# City not found. Skipping...
# Processing Record 28 of Set 11 | san joaquin
# Processing Record 29 of Set 11 | qaqortoq
# Processing Record 30 of Set 11 | hargeysa
# Processing Record 31 of Set 11 | douentza
# Processing Record 32 of Set 11 | palembang
# Processing Record 33 of Set 11 | wenling
# Processing Record 34 of Set 11 | pa sang
# Processing Record 35 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 36 of Set 11 | tilichiki
# Processing Record 37 of Set 11 | blagoyevo
# Processing Record 38 of Set 11 | codrington
# Processing Record 39 of Set 11 | hunchun
# Processing Record 40 of Set 11 | zhuanghe
# Processing Record 41 of Set 11 | pacific grove
# Processing Record 42 of Set 11 | margate
# Processing Record 43 of Set 11 | gat
# Processing Record 44 of Set 11 | sandnessjoen
# Processing Record 45 of Set 11 | chokurdakh
# Processing Record 46 of Set 11 | airai
# Processing Record 47 of Set 11 | camana
# Processing Record 48 of Set 11 | baykit
# Processing Record 49 of Set 11 | tabou
# Processing Record 50 of Set 11 | kinkala
# Processing Record 1 of Set 12 | kruisfontein
# Processing Record 2 of Set 12 | umm kaddadah
# Processing Record 3 of Set 12 | nalvo
# Processing Record 4 of Set 12 | ravar
# Processing Record 5 of Set 12 | inuvik
# Processing Record 6 of Set 12 | dingle
# Processing Record 7 of Set 12 | turinsk
# Processing Record 8 of Set 12 | kalabo
# Processing Record 9 of Set 12 | henties bay
# Processing Record 10 of Set 12 | omsukchan
# Processing Record 11 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 12 of Set 12 | manoel urbano
# Processing Record 13 of Set 12 | sawakin
# Processing Record 14 of Set 12 | dolores
# Processing Record 15 of Set 12 | kenora
# Processing Record 16 of Set 12 | luena
# Processing Record 17 of Set 12 | wabana
# Processing Record 18 of Set 12 | samarai
# Processing Record 19 of Set 12 | eyl
# Processing Record 20 of Set 12 | kingisepp
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | benghazi
# Processing Record 23 of Set 12 | barentu
# Processing Record 24 of Set 12 | moree
# Processing Record 25 of Set 12 | tevaitoa
# Processing Record 26 of Set 12 | otradnoye
# Processing Record 27 of Set 12 | singkang
# Processing Record 28 of Set 12 | barra do bugres
# Processing Record 29 of Set 12 | uyuni
# Processing Record 30 of Set 12 | karpathos
# Processing Record 31 of Set 12 | fugen
# Processing Record 32 of Set 12 | beihai
# Processing Record 33 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 12 | dawei
# Processing Record 35 of Set 12 | alofi
# Processing Record 36 of Set 12 | xinzhou
# Processing Record 37 of Set 12 | oriximina
# Processing Record 38 of Set 12 | batemans bay
# Processing Record 39 of Set 12 | fairbanks
# Processing Record 40 of Set 12 | poronaysk
# Processing Record 41 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 12 | urusha
# Processing Record 43 of Set 12 | puerto del rosario
# Processing Record 44 of Set 12 | lasa
# Processing Record 45 of Set 12 | tobol
# Processing Record 46 of Set 12 | san nicolas
# Processing Record 47 of Set 12 | turukhansk
# Processing Record 48 of Set 12 | mangrol
# Processing Record 49 of Set 12 | cherskiy
# Processing Record 50 of Set 12 | eirunepe
# Processing Record 1 of Set 13 | flinders
# Processing Record 2 of Set 13 | necochea
# Processing Record 3 of Set 13 | ouesso
# Processing Record 4 of Set 13 | canavieiras
# Processing Record 5 of Set 13 | muzhi
# Processing Record 6 of Set 13 | hatillo
# Processing Record 7 of Set 13 | katsuura
# Processing Record 8 of Set 13 | sheltozero
# Processing Record 9 of Set 13 | snasa
# Processing Record 10 of Set 13 | rudsar
# Processing Record 11 of Set 13 | srandakan
# Processing Record 12 of Set 13 | deputatskiy
# Processing Record 13 of Set 13 | tornio
# Processing Record 14 of Set 13 | witbank
# Processing Record 15 of Set 13 | dunedin
# Processing Record 16 of Set 13 | kudamatsu
# Processing Record 17 of Set 13 | ancud
# Processing Record 18 of Set 13 | mabaruma
# Processing Record 19 of Set 13 | eureka
# Processing Record 20 of Set 13 | abha
# Processing Record 21 of Set 13 | chapais
# Processing Record 22 of Set 13 | frontera
# Processing Record 23 of Set 13 | halvad
# Processing Record 24 of Set 13 | klaksvik
# Processing Record 25 of Set 13 | ishigaki
# Processing Record 26 of Set 13 | taitung
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | lebork
# Processing Record 29 of Set 13 | merauke
# Processing Record 30 of Set 13 | ayr
# Processing Record 31 of Set 13 | archidona
# Processing Record 32 of Set 13 | khani
# Processing Record 33 of Set 13 | taoudenni
# Processing Record 34 of Set 13 | carberry
# Processing Record 35 of Set 13 | shaunavon
# Processing Record 36 of Set 13 | tomatlan
# Processing Record 37 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 13 | huambo
# Processing Record 39 of Set 13 | vardenis
# Processing Record 40 of Set 13 | derzhavinsk
# Processing Record 41 of Set 13 | chkalovsk
# Processing Record 42 of Set 13 | flin flon
# Processing Record 43 of Set 13 | makuyuni
# Processing Record 44 of Set 13 | ambilobe
# Processing Record 45 of Set 13 | tabuk
# Processing Record 46 of Set 13 | gobabis
# Processing Record 47 of Set 13 | wanxian
# Processing Record 48 of Set 13 | wuwei
# Processing Record 49 of Set 13 | maraba
# Processing Record 50 of Set 13 | port hardy
# Processing Record 1 of Set 14 | vangaindrano
# Processing Record 2 of Set 14 | bubaque
# Processing Record 3 of Set 14 | jian
# Processing Record 4 of Set 14 | kahului
# Processing Record 5 of Set 14 | rincon
# Processing Record 6 of Set 14 | evanston
# Processing Record 7 of Set 14 | honjo
# Processing Record 8 of Set 14 | anzhero-sudzhensk
# Processing Record 9 of Set 14 | phan thiet
# Processing Record 10 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 14 | chihuahua
# Processing Record 12 of Set 14 | bahir dar
# Processing Record 13 of Set 14 | amilly
# Processing Record 14 of Set 14 | pokhara
# Processing Record 15 of Set 14 | tanout
# Processing Record 16 of Set 14 | sarh
# Processing Record 17 of Set 14 | carnduff
# Processing Record 18 of Set 14 | garissa
# Processing Record 19 of Set 14 | tooele
# Processing Record 20 of Set 14 | denpasar
# Processing Record 21 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 14 | zhigansk
# Processing Record 23 of Set 14 | tessalit
# Processing Record 24 of Set 14 | binzhou
# Processing Record 25 of Set 14 | cayenne
# Processing Record 26 of Set 14 | asau
# Processing Record 27 of Set 14 | preobrazheniye
# Processing Record 28 of Set 14 | comodoro rivadavia
# Processing Record 29 of Set 14 | port lincoln
# Processing Record 30 of Set 14 | taltal
# Processing Record 31 of Set 14 | tanete
# Processing Record 32 of Set 14 | bafra
# Processing Record 33 of Set 14 | sao joao da barra
# Processing Record 34 of Set 14 | colesberg
# Processing Record 35 of Set 14 | santiago del estero
# Processing Record 36 of Set 14 | billings
# Processing Record 37 of Set 14 | gwadar
# Processing Record 38 of Set 14 | bataipora
# Processing Record 39 of Set 14 | homer
# Processing Record 40 of Set 14 | te anau
# Processing Record 41 of Set 14 | solenzo
# Processing Record 42 of Set 14 | whitehorse
# Processing Record 43 of Set 14 | gazanjyk
# Processing Record 44 of Set 14 | hobyo
# Processing Record 45 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 14 | rawson
# Processing Record 47 of Set 14 | kalmar
# Processing Record 48 of Set 14 | acolla
# Processing Record 49 of Set 14 | meulaboh
# Processing Record 50 of Set 14 | high level
# Processing Record 1 of Set 15 | labuhan
# Processing Record 2 of Set 15 | bella union
# Processing Record 3 of Set 15 | praia da vitoria
# Processing Record 4 of Set 15 | kapoeta
# Processing Record 5 of Set 15 | arroio grande
# Processing Record 6 of Set 15 | porto walter
# Processing Record 7 of Set 15 | berbera
# Processing Record 8 of Set 15 | tretten
# Processing Record 9 of Set 15 | miles city
# Processing Record 10 of Set 15 | ilhabela
# Processing Record 11 of Set 15 | vila velha
# Processing Record 12 of Set 15 | veere
# Processing Record 13 of Set 15 | tondano
# Processing Record 14 of Set 15 | leshukonskoye
# Processing Record 15 of Set 15 | matagami
# Processing Record 16 of Set 15 | kitgum
# Processing Record 17 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 15 | oktyabrskiy
# Processing Record 19 of Set 15 | zhanakorgan
# Processing Record 20 of Set 15 | bose
# Processing Record 21 of Set 15 | carutapera
# Processing Record 22 of Set 15 | beyneu
# Processing Record 23 of Set 15 | jacobina
# Processing Record 24 of Set 15 | orapa
# Processing Record 25 of Set 15 | tithorea
# Processing Record 26 of Set 15 | vieques
# Processing Record 27 of Set 15 | dondo
# Processing Record 28 of Set 15 | sesheke
# Processing Record 29 of Set 15 | abu kamal
# Processing Record 30 of Set 15 | evensk
# Processing Record 31 of Set 15 | dori
# Processing Record 32 of Set 15 | sao felix do xingu
# Processing Record 33 of Set 15 | moron
# Processing Record 34 of Set 15 | obodivka
# Processing Record 35 of Set 15 | crossfield
# Processing Record 36 of Set 15 | weihe
# Processing Record 37 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 15 | kiama
# Processing Record 39 of Set 15 | imbituba
# Processing Record 40 of Set 15 | buraydah
# Processing Record 41 of Set 15 | atar
# Processing Record 42 of Set 15 | udachnyy
# Processing Record 43 of Set 15 | qurayyat
# Processing Record 44 of Set 15 | belmonte
# Processing Record 45 of Set 15 | sooke
# Processing Record 46 of Set 15 | buriti alegre
# Processing Record 47 of Set 15 | wildeshausen
# Processing Record 48 of Set 15 | colares
# Processing Record 49 of Set 15 | severnyy-kospashskiy
# Processing Record 50 of Set 15 | mount hagen
# Processing Record 1 of Set 16 | hanahan
# Processing Record 2 of Set 16 | playa del carmen
# Processing Record 3 of Set 16 | pont-rouge
# Processing Record 4 of Set 16 | caruray
# Processing Record 5 of Set 16 | kharakvasla
# Processing Record 6 of Set 16 | khudumelapye
# Processing Record 7 of Set 16 | santa rosa
# Processing Record 8 of Set 16 | bida
# Processing Record 9 of Set 16 | de aar
# Processing Record 10 of Set 16 | sisimiut
# Processing Record 11 of Set 16 | skjervoy
# Processing Record 12 of Set 16 | pochutla
# Processing Record 13 of Set 16 | mareeba
# Processing Record 14 of Set 16 | letterkenny
# Processing Record 15 of Set 16 | marzuq
# Processing Record 16 of Set 16 | kaoma
# Processing Record 17 of Set 16 | nagorsk
# Processing Record 18 of Set 16 | lagos
# Processing Record 19 of Set 16 | cairns
# Processing Record 20 of Set 16 | hanchuan
# Processing Record 21 of Set 16 | tres arroyos
# Processing Record 22 of Set 16 | bedesa
# Processing Record 23 of Set 16 | severo-yeniseyskiy
# Processing Record 24 of Set 16 | riyadh
# Processing Record 25 of Set 16 | mashhad
# Processing Record 26 of Set 16 | sinnamary
# Processing Record 27 of Set 16 | nieuwpoort
# Processing Record 28 of Set 16 | tianmen
# Processing Record 29 of Set 16 | zaozerne
# Processing Record 30 of Set 16 | alamosa
# Processing Record 31 of Set 16 | wad rawah
# Processing Record 32 of Set 16 | mayya
# Processing Record 33 of Set 16 | kirensk
# Processing Record 34 of Set 16 | awjilah
# Processing Record 35 of Set 16 | obo
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
len(city_data)
# Out:
# 734

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Chuy      UY -33.6971  -53.4616     69.30        88         100
# 1           Hobart      AU -42.8794  147.3294     61.00        63          40
# 2             Roma      US  43.2128  -75.4557     48.20        57           1
# 3           Barrow      US  71.2906 -156.7887    -11.20        77           1
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     80.60        69           0
# 5     Punta Arenas      CL -53.1500  -70.9167     51.01        62          20
# 6          Qesarya      IL  32.5189   34.9046     57.20        54          40
# 7          Rikitea      PF -23.1203 -134.9692     79.79        68           1
# 8       Winchester      GB  51.0651   -1.3187     48.99        87          75
# 9          Ushuaia      AR -54.8000  -68.3000     55.40        76          40
#
#    Wind Speed Current Description
# 0        3.67     overcast clouds
# 1       14.97    scattered clouds
# 2        6.91           clear sky
# 3        5.75           clear sky
# 4       10.36           clear sky
# 5       43.73          light rain
# 6        2.30    scattered clouds
# 7       18.05           clear sky
# 8       10.36       broken clouds
# 9       17.27       moderate rain

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
